# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# ## Curación de los datos:

# %%
# Importar archivo excel con la base de datos de los viajes.
data = pd.read_excel(r"C:\Users\User\Documents\GitHub\DiploDatos\Informe_viajes\Viajes.xlsx")
data.head(30)
# Out:
#               Unnamed: 0          Unnamed: 1 Unnamed: 2      Unnamed: 3  \
# 0                    NaN                 NaN        NaN             NaN
# 1                    NaN                 NaN        NaN             NaN
# 2                    NaN                 NaN        NaN             NaN
# 3                    NaN                 NaN        NaN             NaN
# 4                    NaN                 NaN        NaN             NaN
# 5                    NaN                 NaN        NaN             NaN
# 6                    NaN                 NaN        NaN             NaN
# 7                    NaN                 NaN        NaN             NaN
# 8                    NaN                 NaN        NaN             NaN
# 9               LP_Fecha             (Todas)        NaN             NaN
# 10        CodigoProducto             (Todas)        NaN             NaN
# 11           Cuil_Chofer             (Todas)        NaN             NaN
# 12              lp_Total             (Todas)        NaN             NaN
# 13  OrdenViaje_Kilometro             (Todas)        NaN             NaN
# 14             LP_Nombre             (Todas)        NaN             NaN
# 15                tarifa             (Todas)        NaN             NaN
# 16              custodia             (Todas)        NaN             NaN
# 17         Factura_Fecha             (Todas)        NaN             NaN
# 18     OrdenViaje_Nombre             (Todas)        NaN             NaN
# 19        Factura_Nombre             (Todas)        NaN             NaN
# 20     Provincia_Destino             (Todas)        NaN             NaN
# 21      Provincia_Origen             (Todas)        NaN             NaN
# 22     OrdenViaje_Estado  (Varios elementos)        NaN             NaN
# 23                   NaN                 NaN        NaN             NaN
# 24               Importe                 NaN        NaN             NaN
# 25                 Fecha              Equipo   Acoplado          Origen
# 26            0017-12-01              IIJ763     WYH974  SAN LUIS-ARCOR
# 27            0201-04-22              LVF515     JUY548  ARROYITO-ARCOR
# 28            0202-09-12              IIJ763     WYH974    SALTO-BAGLEY
# 29            0207-11-01              FUB431     GBN276    RECREO-ARCOR
#
#         Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0              NaN        NaN         NaN        NaN        NaN
# 1              NaN        NaN         NaN        NaN        NaN
# 2              NaN        NaN         NaN        NaN        NaN
# 3              NaN        NaN         NaN        NaN        NaN
# 4              NaN        NaN         NaN        NaN        NaN
# 5              NaN        NaN         NaN        NaN        NaN
# 6              NaN        NaN         NaN        NaN        NaN
# 7              NaN        NaN         NaN        NaN        NaN
# 8              NaN        NaN         NaN        NaN        NaN
# 9              NaN        NaN         NaN        NaN        NaN
# 10             NaN        NaN         NaN        NaN        NaN
# 11             NaN        NaN         NaN        NaN        NaN
# 12             NaN        NaN         NaN        NaN        NaN
# 13             NaN        NaN         NaN        NaN        NaN
# 14             NaN        NaN         NaN        NaN        NaN
# 15             NaN        NaN         NaN        NaN        NaN
# 16             NaN        NaN         NaN        NaN        NaN
# 17             NaN        NaN         NaN        NaN        NaN
# 18             NaN        NaN         NaN        NaN        NaN
# 19             NaN        NaN         NaN        NaN        NaN
# 20             NaN        NaN         NaN        NaN        NaN
# 21             NaN        NaN         NaN        NaN        NaN
# 22             NaN        NaN         NaN        NaN        NaN
# 23             NaN        NaN         NaN        NaN        NaN
# 24             NaN        NaN         NaN        NaN        NaN
# 25         Destino    Cliente  Mercaderia         Km         Kg
# 26   TUCUMAN-ARCOR      VACIO      VACIOS        870          0
# 27   TUCUMAN-ARCOR      VACIO      VACIOS        700          0
# 28  ARROYITO-ARCOR      VACIO      VACIOS        508          0
# 29   TUCUMAN-ARCOR      VACIO      VACIOS        275          0
#
#                   Unnamed: 9             Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0                        NaN                     NaN         NaN         NaN
# 1                        NaN                     NaN         NaN         NaN
# 2                        NaN                     NaN         NaN         NaN
# 3                        NaN                     NaN         NaN         NaN
# 4                        NaN                     NaN         NaN         NaN
# 5                        NaN                     NaN         NaN         NaN
# 6                        NaN                     NaN         NaN         NaN
# 7                        NaN                     NaN         NaN         NaN
# 8                        NaN                     NaN         NaN         NaN
# 9                        NaN                     NaN         NaN         NaN
# 10                       NaN                     NaN         NaN         NaN
# 11                       NaN                     NaN         NaN         NaN
# 12                       NaN                     NaN         NaN         NaN
# 13                       NaN                     NaN         NaN         NaN
# 14                       NaN                     NaN         NaN         NaN
# 15                       NaN                     NaN         NaN         NaN
# 16                       NaN                     NaN         NaN         NaN
# 17                       NaN                     NaN         NaN         NaN
# 18                       NaN                     NaN         NaN         NaN
# 19                       NaN                     NaN         NaN         NaN
# 20                       NaN                     NaN         NaN         NaN
# 21                       NaN                     NaN         NaN         NaN
# 22                       NaN                     NaN         NaN         NaN
# 23                       NaN                     NaN         NaN         NaN
# 24                       NaN                     NaN         NaN         NaN
# 25                    Chofer                 Fletero    N° Viaje       Total
# 26  POPULIN NORBERTO ERNESTO        POPULIN NORBERTO         NaN           0
# 27     LUQUE MIGUEL MERCEDES  GIACONE ERMINDO FABIAN         NaN           0
# 28  POPULIN NORBERTO ERNESTO        POPULIN NORBERTO         NaN           0
# 29        MAGLIANO DANIEL M.   CUGNO GABRIEL ROBERTO         NaN           0

# %%
# Eliminar filas sobrantes(NaN) al comienzo del dataframe.
data = data.drop(data.index[0:32])
data.tail(8)
# Out:
#           Unnamed: 0 Unnamed: 1 Unnamed: 2                        Unnamed: 3  \
# 65616            NaN     OXJ862    AC121PL            VIRREY DEL PINO-MANAOS
# 65617            NaN     HVW275    AC967YM                    ARROYITO-ARCOR
# 65618            NaN     MMN838     HPK860                    ARROYITO-ARCOR
# 65619            NaN     JJA110     JUY549  GENERAL ALVEAR-LABORATORIO DEWEY
# 65620            NaN    AB687SH     LEV414                    ARROYITO-ARCOR
# 65621            NaN    AD533SA     KKM746                     TUCUMAN-ARCOR
# 65622            NaN     EKW438     JRY687                    ARROYITO-ARCOR
# 65623  Total general        NaN        NaN                               NaN
#
#                                          Unnamed: 4     Unnamed: 5 Unnamed: 6  \
# 65616                                ARROYITO-ARCOR          VACIO     VACIOS
# 65617                          VILLA MERCEDES-ARCOR  INGRECOR S.A.    GLUCOSA
# 65618  LA BANDA - SANTIAGO DEL ESTERO-PRODUNOA S.A.  INGRECOR S.A.    GLUCOSA
# 65619                                ARROYITO-ARCOR          VACIO     VACIOS
# 65620                          VILLA MERCEDES-ARCOR  INGRECOR S.A.    GLUCOSA
# 65621                                ARROYITO-ARCOR  INGRECOR S.A.    GLUCOSA
# 65622                        VIRREY DEL PINO-MANAOS  INGRECOR S.A.    GLUCOSA
# 65623                                           NaN            NaN        NaN
#
#       Unnamed: 7 Unnamed: 8              Unnamed: 9          Unnamed: 10  \
# 65616        671          0           QUIROGA LUCAS   TRANSPORTE VIAR SA
# 65617        450        NaN                     NaN                  NaN
# 65618        528          0   BOSETTI JORGE ALBERTO   TRANSPORTE VIAR SA
# 65619        815          0     GENTA MATIAS DANIEL  GENTA MATIAS DANIEL
# 65620        450        NaN                     NaN                  NaN
# 65621        700          0  FICETTI ANGEL LEONARDO   TRANSPORTE VIAR SA
# 65622        671          0      BRIGNONE JUAN JOSE   BRIGNONE JUAN JOSE
# 65623        NaN        NaN                     NaN                  NaN
#
#       Unnamed: 11        Unnamed: 12
# 65616         NaN                  0
# 65617         NaN                  0
# 65618         NaN                  0
# 65619         NaN                  0
# 65620         NaN                  0
# 65621         NaN                  0
# 65622         NaN                  0
# 65623         NaN  1454256972.670038

# %%
# Eliminar fila "Total general".
data = data.drop([65623],axis=0)
data.tail()
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2                        Unnamed: 3  \
# 65618        NaN     MMN838     HPK860                    ARROYITO-ARCOR
# 65619        NaN     JJA110     JUY549  GENERAL ALVEAR-LABORATORIO DEWEY
# 65620        NaN    AB687SH     LEV414                    ARROYITO-ARCOR
# 65621        NaN    AD533SA     KKM746                     TUCUMAN-ARCOR
# 65622        NaN     EKW438     JRY687                    ARROYITO-ARCOR
#
#                                          Unnamed: 4     Unnamed: 5 Unnamed: 6  \
# 65618  LA BANDA - SANTIAGO DEL ESTERO-PRODUNOA S.A.  INGRECOR S.A.    GLUCOSA
# 65619                                ARROYITO-ARCOR          VACIO     VACIOS
# 65620                          VILLA MERCEDES-ARCOR  INGRECOR S.A.    GLUCOSA
# 65621                                ARROYITO-ARCOR  INGRECOR S.A.    GLUCOSA
# 65622                        VIRREY DEL PINO-MANAOS  INGRECOR S.A.    GLUCOSA
#
#       Unnamed: 7 Unnamed: 8              Unnamed: 9          Unnamed: 10  \
# 65618        528          0   BOSETTI JORGE ALBERTO   TRANSPORTE VIAR SA
# 65619        815          0     GENTA MATIAS DANIEL  GENTA MATIAS DANIEL
# 65620        450        NaN                     NaN                  NaN
# 65621        700          0  FICETTI ANGEL LEONARDO   TRANSPORTE VIAR SA
# 65622        671          0      BRIGNONE JUAN JOSE   BRIGNONE JUAN JOSE
#
#       Unnamed: 11 Unnamed: 12
# 65618         NaN           0
# 65619         NaN           0
# 65620         NaN           0
# 65621         NaN           0
# 65622         NaN           0

# %%
# Nombrar las columnas con la fila 26. 
data.columns = [
    "Fecha","Equipo","Acoplado",
    "Origen","Destino","Cliente",
    "Mercaderia","Km","Kg","Chofer",
    "Fletero","NroViaje","Total$"
    ]

# %%
data.head(15)
# Out:
#          Fecha  Equipo Acoplado                   Origen  \
# 32  2015-04-23  HVW275   SKQ158           ARROYITO-ARCOR
# 33  2015-06-12  KGN796   HPK860           ARROYITO-ARCOR
# 34  2015-06-27  KMU569   KNA507  VILLA MERCEDES-GLUCOVIL
# 35  2015-06-30  EPR172   VMY280     VILLA MERCEDES-ARCOR
# 36  2015-07-03  FWT826   RJE024            TUCUMAN-ARCOR
# 37         NaN  GAT032   LEV414            TUCUMAN-ARCOR
# 38         NaN  GUZ764   JIS373           ARROYITO-ARCOR
# 39  2015-07-07  HGI971   KKM746           ARROYITO-ARCOR
# 40  2015-07-10  EQN486   HPK860           ARROYITO-ARCOR
# 41         NaN  GUZ764   JIS373           ARROYITO-ARCOR
# 42         NaN  HFJ834   JUY548           ARROYITO-ARCOR
# 43         NaN  HVW275   SKQ158           ARROYITO-ARCOR
# 44  2015-07-11  HWF024   DKP501            TUCUMAN-ARCOR
# 45  2015-07-13  FFL175   JUY549           ARROYITO-ARCOR
# 46         NaN  GAT032   LEV414           ARROYITO-ARCOR
#
#                                  Destino                 Cliente  \
# 32             LUJAN- ICE CREAM  HELADOS          ARCOR S.A.I.C.
# 33            VIRREY DEL PINO-REFRES NOW          ARCOR S.A.I.C.
# 34                    GODOY CRUZ-QUILMES  GLUCOVIL ARGENTINA S.A
# 35                        SAN LUIS-ARCOR          ARCOR S.A.I.C.
# 36                        SAN LUIS-ARCOR          ARCOR S.A.I.C.
# 37  SAUCE VIEJO-CIA.INDUSTRIAL CERVECERA          ARCOR S.A.I.C.
# 38                         CORDOBA-PRITY          ARCOR S.A.I.C.
# 39                      CONCORDIA-BAGGIO          ARCOR S.A.I.C.
# 40                     MONTE VERA-FRUNAT          ARCOR S.A.I.C.
# 41                VIRREY DEL PINO-MANAOS          ARCOR S.A.I.C.
# 42                VIRREY DEL PINO-MANAOS          ARCOR S.A.I.C.
# 43                  VILLA MERCEDES-ARCOR          ARCOR S.A.I.C.
# 44                         TUCUMAN-ARCOR          ARCOR S.A.I.C.
# 45                VIRREY DEL PINO-MANAOS          ARCOR S.A.I.C.
# 46                VIRREY DEL PINO-MANAOS          ARCOR S.A.I.C.
#
#         Mercaderia   Km     Kg                   Chofer  \
# 32         GLUCOSA  630      0      GIRAUDO VICTOR HUGO
# 33         GLUCOSA    0      0         QUINTEROS MIGUEL
# 34  AGUAS GASEOSAS  704  28670           CORDOBA SERGIO
# 35   PASTA DE MANI    0      0         GUAL RUBEN DARIO
# 36         GLUCOSA    0      0  TUNINETTI, JAVIER OSCAR
# 37         GLUCOSA    0      0         BERTOSSI MARCELO
# 38         GLUCOSA    0      0             VARELA FAVIO
# 39         GLUCOSA    0      0       PERALTA MARCELO A.
# 40         GLUCOSA    0      0            PERALTA JORGE
# 41         GLUCOSA    0      0             VARELA FAVIO
# 42         GLUCOSA    0      0               GUAL JORGE
# 43         GLUCOSA    0      0      GIRAUDO VICTOR HUGO
# 44           GRASA    0      0   BRUNOTTO JORGE AGUSTIN
# 45         GLUCOSA    0      0        VILLARRUEL MARTIN
# 46         GLUCOSA    0      0         BERTOSSI MARCELO
#
#                     Fletero         NroViaje   Total$
# 32          SANCHEZ ISOLINA         1581670*  3920.67
# 33    CUGNO GABRIEL ROBERTO         1610321*  2445.26
# 34       TRANSPORTE VIAR SA       181-129059  9216.14
# 35         GUAL RUBEN DARIO          1620779  5863.12
# 36       TRANSPORTE VIAR SA          1623365    123.5
# 37  TURCHETTI ANGEL Y OTROS  1623367 ESTADIA  4560.15
# 38   MININ MANUEL FRANCISCO          1622160  3153.76
# 39       TRANSPORTE STUD SA         1624705*  3469.69
# 40   MININ MANUEL FRANCISCO          1625576   109.84
# 41   MININ MANUEL FRANCISCO          1627055  2726.21
# 42         GUAL RUBEN DARIO          1627046  2425.93
# 43          SANCHEZ ISOLINA          1627196   536.49
# 44       TRANSPORTE VIAR SA         1627519*  1046.24
# 45        GOYENECHEA HECTOR          1627698  2511.51
# 46  TURCHETTI ANGEL Y OTROS          1627695  2530.72

# %%
data.shape
# Out:
# (65591, 13)

# %%
# Rellenar los NaN de Fecha con los valores de fecha anteriores.
data["Fecha"] = data["Fecha"].fillna( method="pad") 
data.tail(10)
# Out:
#             Fecha   Equipo Acoplado                            Origen  \
# 65613  2022-02-02  AD414GZ  AE205GV           LA QUIACA-MOLINOS VIADA
# 65614  2022-02-02   KSS334   GBN276                    ARROYITO-ARCOR
# 65615  2022-02-03   HWF024   VMY280                     TICINO-TICINO
# 65616  2022-02-03   OXJ862  AC121PL            VIRREY DEL PINO-MANAOS
# 65617  2022-02-03   HVW275  AC967YM                    ARROYITO-ARCOR
# 65618  2022-02-03   MMN838   HPK860                    ARROYITO-ARCOR
# 65619  2022-02-03   JJA110   JUY549  GENERAL ALVEAR-LABORATORIO DEWEY
# 65620  2022-02-03  AB687SH   LEV414                    ARROYITO-ARCOR
# 65621  2022-02-03  AD533SA   KKM746                     TUCUMAN-ARCOR
# 65622  2022-02-03   EKW438   JRY687                    ARROYITO-ARCOR
#
#                                             Destino         Cliente  \
# 65613      LIBERTADOR GRAL SAN MARTIN JUJUY-LEDESMA           VACIO
# 65614                            BURZACO-CEPAS ARG.   INGRECOR S.A.
# 65615                          COLONIA CAROYA-ARCOR  ARCOR S.A.I.C.
# 65616                                ARROYITO-ARCOR           VACIO
# 65617                          VILLA MERCEDES-ARCOR   INGRECOR S.A.
# 65618  LA BANDA - SANTIAGO DEL ESTERO-PRODUNOA S.A.   INGRECOR S.A.
# 65619                                ARROYITO-ARCOR           VACIO
# 65620                          VILLA MERCEDES-ARCOR   INGRECOR S.A.
# 65621                                ARROYITO-ARCOR   INGRECOR S.A.
# 65622                        VIRREY DEL PINO-MANAOS   INGRECOR S.A.
#
#           Mercaderia   Km   Kg                     Chofer  \
# 65613         VACIOS  395    0  NARETTO FRANCISCO ANTONIO
# 65614        GLUCOSA  672    0        CUGNO EDGARDO RUBEN
# 65615  PASTA DE MANI  250    0            FERREYRA CARLOS
# 65616         VACIOS  671    0              QUIROGA LUCAS
# 65617        GLUCOSA  450  NaN                        NaN
# 65618        GLUCOSA  528    0      BOSETTI JORGE ALBERTO
# 65619         VACIOS  815    0        GENTA MATIAS DANIEL
# 65620        GLUCOSA  450  NaN                        NaN
# 65621        GLUCOSA  700    0     FICETTI ANGEL LEONARDO
# 65622        GLUCOSA  671    0         BRIGNONE JUAN JOSE
#
#                    Fletero NroViaje Total$
# 65613   TRANSPORTE VIAR SA      NaN      0
# 65614  CUGNO EDGARDO RUBEN      NaN      0
# 65615   TRANSPORTE VIAR SA      NaN      0
# 65616   TRANSPORTE VIAR SA      NaN      0
# 65617                  NaN      NaN      0
# 65618   TRANSPORTE VIAR SA      NaN      0
# 65619  GENTA MATIAS DANIEL      NaN      0
# 65620                  NaN      NaN      0
# 65621   TRANSPORTE VIAR SA      NaN      0
# 65622   BRIGNONE JUAN JOSE      NaN      0

# %%
# Separar columna Fecha en Mes y Año.
data["Fecha"] = pd.to_datetime(data["Fecha"]) 
data["Año"] = data["Fecha"].dt.year 
data["Mes"] = data["Fecha"].dt.month 
data.head()
# Out:
#         Fecha  Equipo Acoplado                   Origen  \
# 32 2015-04-23  HVW275   SKQ158           ARROYITO-ARCOR
# 33 2015-06-12  KGN796   HPK860           ARROYITO-ARCOR
# 34 2015-06-27  KMU569   KNA507  VILLA MERCEDES-GLUCOVIL
# 35 2015-06-30  EPR172   VMY280     VILLA MERCEDES-ARCOR
# 36 2015-07-03  FWT826   RJE024            TUCUMAN-ARCOR
#
#                        Destino                 Cliente      Mercaderia   Km  \
# 32   LUJAN- ICE CREAM  HELADOS          ARCOR S.A.I.C.         GLUCOSA  630
# 33  VIRREY DEL PINO-REFRES NOW          ARCOR S.A.I.C.         GLUCOSA    0
# 34          GODOY CRUZ-QUILMES  GLUCOVIL ARGENTINA S.A  AGUAS GASEOSAS  704
# 35              SAN LUIS-ARCOR          ARCOR S.A.I.C.   PASTA DE MANI    0
# 36              SAN LUIS-ARCOR          ARCOR S.A.I.C.         GLUCOSA    0
#
#        Kg                   Chofer                Fletero    NroViaje  \
# 32      0      GIRAUDO VICTOR HUGO        SANCHEZ ISOLINA    1581670*
# 33      0         QUINTEROS MIGUEL  CUGNO GABRIEL ROBERTO    1610321*
# 34  28670           CORDOBA SERGIO     TRANSPORTE VIAR SA  181-129059
# 35      0         GUAL RUBEN DARIO       GUAL RUBEN DARIO     1620779
# 36      0  TUNINETTI, JAVIER OSCAR     TRANSPORTE VIAR SA     1623365
#
#      Total$   Año  Mes
# 32  3920.67  2015    4
# 33  2445.26  2015    6
# 34  9216.14  2015    6
# 35  5863.12  2015    6
# 36    123.5  2015    7

# %% [markdown]
# # Armado de informe viajes corta y larga distancia

# %% [markdown]
# **Obejtivo del informe:**
# Contabilizar en forma mensual los viajes de glucosa del cliente ARCOR. Clasificandolos en viajes de corta y larga distancia.

# %%
# Filtrar por cliente "ARCOR S.A.I.C." e "INGRECOR S.A.".
df_mask = data[(data["Cliente"] == "ARCOR S.A.I.C.") | (data["Cliente"] == "INGRECOR S.A.")] 
data = df_mask
data.head()
# Out:
#         Fecha  Equipo Acoplado                Origen  \
# 32 2015-04-23  HVW275   SKQ158        ARROYITO-ARCOR
# 33 2015-06-12  KGN796   HPK860        ARROYITO-ARCOR
# 35 2015-06-30  EPR172   VMY280  VILLA MERCEDES-ARCOR
# 36 2015-07-03  FWT826   RJE024         TUCUMAN-ARCOR
# 37 2015-07-03  GAT032   LEV414         TUCUMAN-ARCOR
#
#                                  Destino         Cliente     Mercaderia   Km  \
# 32             LUJAN- ICE CREAM  HELADOS  ARCOR S.A.I.C.        GLUCOSA  630
# 33            VIRREY DEL PINO-REFRES NOW  ARCOR S.A.I.C.        GLUCOSA    0
# 35                        SAN LUIS-ARCOR  ARCOR S.A.I.C.  PASTA DE MANI    0
# 36                        SAN LUIS-ARCOR  ARCOR S.A.I.C.        GLUCOSA    0
# 37  SAUCE VIEJO-CIA.INDUSTRIAL CERVECERA  ARCOR S.A.I.C.        GLUCOSA    0
#
#    Kg                   Chofer                  Fletero         NroViaje  \
# 32  0      GIRAUDO VICTOR HUGO          SANCHEZ ISOLINA         1581670*
# 33  0         QUINTEROS MIGUEL    CUGNO GABRIEL ROBERTO         1610321*
# 35  0         GUAL RUBEN DARIO         GUAL RUBEN DARIO          1620779
# 36  0  TUNINETTI, JAVIER OSCAR       TRANSPORTE VIAR SA          1623365
# 37  0         BERTOSSI MARCELO  TURCHETTI ANGEL Y OTROS  1623367 ESTADIA
#
#      Total$   Año  Mes
# 32  3920.67  2015    4
# 33  2445.26  2015    6
# 35  5863.12  2015    6
# 36    123.5  2015    7
# 37  4560.15  2015    7

# %%
# Filtrar por Origen igual "ARROYITO-ARCOR" y Mercaderia igual "GLUCOSA".
df_mask = data[(data["Origen"] == "ARROYITO-ARCOR") & (data["Mercaderia"] == "GLUCOSA")]
data = df_mask
data.head()
# Out:
#         Fecha  Equipo Acoplado          Origen                     Destino  \
# 32 2015-04-23  HVW275   SKQ158  ARROYITO-ARCOR   LUJAN- ICE CREAM  HELADOS
# 33 2015-06-12  KGN796   HPK860  ARROYITO-ARCOR  VIRREY DEL PINO-REFRES NOW
# 38 2015-07-03  GUZ764   JIS373  ARROYITO-ARCOR               CORDOBA-PRITY
# 39 2015-07-07  HGI971   KKM746  ARROYITO-ARCOR            CONCORDIA-BAGGIO
# 40 2015-07-10  EQN486   HPK860  ARROYITO-ARCOR           MONTE VERA-FRUNAT
#
#            Cliente Mercaderia   Km Kg               Chofer  \
# 32  ARCOR S.A.I.C.    GLUCOSA  630  0  GIRAUDO VICTOR HUGO
# 33  ARCOR S.A.I.C.    GLUCOSA    0  0     QUINTEROS MIGUEL
# 38  ARCOR S.A.I.C.    GLUCOSA    0  0         VARELA FAVIO
# 39  ARCOR S.A.I.C.    GLUCOSA    0  0   PERALTA MARCELO A.
# 40  ARCOR S.A.I.C.    GLUCOSA    0  0        PERALTA JORGE
#
#                    Fletero  NroViaje   Total$   Año  Mes
# 32         SANCHEZ ISOLINA  1581670*  3920.67  2015    4
# 33   CUGNO GABRIEL ROBERTO  1610321*  2445.26  2015    6
# 38  MININ MANUEL FRANCISCO   1622160  3153.76  2015    7
# 39      TRANSPORTE STUD SA  1624705*  3469.69  2015    7
# 40  MININ MANUEL FRANCISCO   1625576   109.84  2015    7

# %%
data.shape
# Out:
# (11885, 15)

# %%
# Filtrar viajes sin estadias y ajustes.
data = data[~data.NroViaje.str.contains("Ajus|EST", na=False, case=False)]
data.shape
# Out:
# (11266, 15)

# %%
# Eliminar año 2015 y Mercaderia igual a "VACIOS".
data = data.drop(data[data["Año"]==2015].index) 
data = data.drop(data[data["Mercaderia"]=="VACIOS"].index)

# %%
data.head()
# Out:
#           Fecha  Equipo Acoplado          Origen           Destino  \
# 2362 2016-01-02  HPJ126   GON266  ARROYITO-ARCOR  CHASCOMUS-DANONE
# 2364 2016-01-03  FWT827   KKM746  ARROYITO-ARCOR    ARROYITO-ARCOR
# 2373 2016-01-04  EZZ647   JIS241  ARROYITO-ARCOR  CHASCOMUS-DANONE
# 2374 2016-01-04  FBO520   GET034  ARROYITO-ARCOR  CHASCOMUS-DANONE
# 2375 2016-01-04  FNR395   GKQ545  ARROYITO-ARCOR     CORDOBA-EDASA
#
#              Cliente Mercaderia    Km     Kg                     Chofer  \
# 2362  ARCOR S.A.I.C.    GLUCOSA  1680  28900               CUGNO MARTIN
# 2364  ARCOR S.A.I.C.    GLUCOSA    10  26440       ACEVEDO HUGO ANTONIO
# 2373  ARCOR S.A.I.C.    GLUCOSA  1680  28820      BOSETTI JORGE ALBERTO
# 2374  ARCOR S.A.I.C.    GLUCOSA  1680  28040        GOYENECHEA CRISTIAN
# 2375  ARCOR S.A.I.C.    GLUCOSA   700  28460  CHIAMBRETTO, WALTER CESAR
#
#                      Fletero NroViaje    Total$   Año  Mes
# 2362    CUGNO ROBERTO MARTÍN  1727370  23584.13  2016    1
# 2364      TRANSPORTE VIAR SA  1727372   1835.31  2016    1
# 2373  MININ MANUEL FRANCISCO  1727371  23518.85  2016    1
# 2374       GOYENECHEA HECTOR  1727409  22882.32  2016    1
# 2375      TRANSPORTE VIAR SA  1728035   3737.96  2016    1

# %%
data.shape
# Out:
# (10451, 15)

# %%
# Verificar que no existan filas en la columna Mercaderia con "VACIOS".
vacios = (data[data["Mercaderia"]=="VACIOS"].index)
df_vacios = pd.DataFrame(vacios)
len(df_vacios)
# Out:
# 0

# %%
# Crear un subconjunto con viajes de corta distancia(considerados los menores o iguales a 150 kilometros).
df_mask = data["Km"]<=150 
subset_ds = data[df_mask]

# %%
len(subset_ds)
# Out:
# 3093

# %%
# Crear un subconjunto con viajes de larga  distancia(considerados los mayores a 150 kilometros).
df_mask = data["Km"]>150
subset_dl = data[df_mask]

# %%
len(subset_dl)
# Out:
# 7358

# %%
# Control de suma de viajes subconjuntos vs conjunto. Prueba OK.
len(subset_ds) + len(subset_dl) - len(data)
# Out:
# 0

# %%
# Renombrar subset_ds con A para simplificar.
A = subset_ds
# Transformar columna Fecha en index del dataframe.
A["Fecha"] = pd.to_datetime(A["Fecha"], format="%m/%y")
A.index = A["Fecha"]
# Aplicar metodo resample para agrupar y contar por mes la cantidad de los viajes.
A = A.resample("M").count()
A = pd.DataFrame(A["Mes"])
A.head()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_7192/3968647109.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   A["Fecha"] = pd.to_datetime(A["Fecha"], format="%m/%y")
#             Mes
# Fecha
# 2016-01-31   29
# 2016-02-29   36
# 2016-03-31   21
# 2016-04-30   21
# 2016-05-31   30

# %%
# Renombrar subset_dl con B para simplificar.
B = subset_dl
B.head()
# Transformar columna Fecha en index del dataframe.
B["Fecha"] = pd.to_datetime(B["Fecha"], format="%m/%y")
B.index = B["Fecha"]
# Aplicar metodo resample para agrupar y contar por mes la cantidad de los viajes.
B = B.resample("M").count()
B = pd.DataFrame(B["Mes"])
B.head()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_7192/3544735658.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   B["Fecha"] = pd.to_datetime(B["Fecha"], format="%m/%y")
#             Mes
# Fecha
# 2016-01-31   88
# 2016-02-29   44
# 2016-03-31   88
# 2016-04-30   77
# 2016-05-31   69

# %%
A.columns = ["Corta distancia"]
B.columns = ["Larga distancia"]

# %%
# Unir en un solo dataframe los viajes de corta(A) y larga distancia(B).
df_innerAB = A.merge(B, how="inner", left_index=True, right_index=True)

# %%
df_innerAB.head()
# Out:
#             Corta distancia  Larga distancia
# Fecha
# 2016-01-31               29               88
# 2016-02-29               36               44
# 2016-03-31               21               88
# 2016-04-30               21               77
# 2016-05-31               30               69

# %%
df_innerAB["index"] = df_innerAB.index #Cambiar nombre de columna Index a fecha!!!!
df_innerAB["index"] = pd.to_datetime(df_innerAB["index"])
df_innerAB["Total"] = df_innerAB["Corta distancia"] + df_innerAB["Larga distancia"]
df_innerAB["%Cd"] = (df_innerAB["Corta distancia"] / df_innerAB["Total"]) * 100
df_innerAB["%Ld"] = (df_innerAB["Larga distancia"] / df_innerAB["Total"]) * 100
df_innerAB["%Total"] = (df_innerAB["Total"] / df_innerAB["Total"]) * 100
df_innerAB.head()
# Out:
#             Corta distancia  Larga distancia      index  Total        %Cd  \
# Fecha
# 2016-01-31               29               88 2016-01-31    117  24.786325
# 2016-02-29               36               44 2016-02-29     80  45.000000
# 2016-03-31               21               88 2016-03-31    109  19.266055
# 2016-04-30               21               77 2016-04-30     98  21.428571
# 2016-05-31               30               69 2016-05-31     99  30.303030
#
#                   %Ld  %Total
# Fecha
# 2016-01-31  75.213675   100.0
# 2016-02-29  55.000000   100.0
# 2016-03-31  80.733945   100.0
# 2016-04-30  78.571429   100.0
# 2016-05-31  69.696970   100.0

# %%
# Ordenar las columnas.
df_innerAB = df_innerAB[["index","Corta distancia",
                         "Larga distancia","Total",
                         "%Cd","%Ld","%Total"
                         ]]
df_innerAB.sort_values(by="index",ascending=False)  
df_innerAB.tail()
# Out:
#                 index  Corta distancia  Larga distancia  Total        %Cd  \
# Fecha
# 2021-10-31 2021-10-31               24              135    159  15.094340
# 2021-11-30 2021-11-30               41              135    176  23.295455
# 2021-12-31 2021-12-31               55              108    163  33.742331
# 2022-01-31 2022-01-31               61               93    154  39.610390
# 2022-02-28 2022-02-28                6               16     22  27.272727
#
#                   %Ld  %Total
# Fecha
# 2021-10-31  84.905660   100.0
# 2021-11-30  76.704545   100.0
# 2021-12-31  66.257669   100.0
# 2022-01-31  60.389610   100.0
# 2022-02-28  72.727273   100.0

# %%
# Calcular la media de los viajes. 
df_innerAB["Media_Cd"] = np.mean(df_innerAB["Corta distancia"])
df_innerAB["Media_Ld"] = np.mean(df_innerAB["Larga distancia"])
df_innerAB["Media_To"] = np.mean(df_innerAB["Total"])
df_innerAB.head()
# Out:
#                 index  Corta distancia  Larga distancia  Total        %Cd  \
# Fecha
# 2016-01-31 2016-01-31               29               88    117  24.786325
# 2016-02-29 2016-02-29               36               44     80  45.000000
# 2016-03-31 2016-03-31               21               88    109  19.266055
# 2016-04-30 2016-04-30               21               77     98  21.428571
# 2016-05-31 2016-05-31               30               69     99  30.303030
#
#                   %Ld  %Total   Media_Cd   Media_Ld   Media_To
# Fecha
# 2016-01-31  75.213675   100.0  41.797297  99.432432  141.22973
# 2016-02-29  55.000000   100.0  41.797297  99.432432  141.22973
# 2016-03-31  80.733945   100.0  41.797297  99.432432  141.22973
# 2016-04-30  78.571429   100.0  41.797297  99.432432  141.22973
# 2016-05-31  69.696970   100.0  41.797297  99.432432  141.22973

# %%
# Generar archivo excel de la base de viajes totales luego del proceso de curación de datos. 
data.to_excel(r"C:\Users\User\Documents\GitHub\DiploDatos\Informe_viajes\Informe\baseviajes.xlsx", index=True)

# %%
# Generar archivo excel del informe de viajes de corta y larga distancia.
df_innerAB.to_excel(r"C:\Users\User\Documents\GitHub\DiploDatos\Informe_viajes\Informe\cant_viajes.xlsx", index=False)
